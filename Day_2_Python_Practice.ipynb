# %%
name = "Sadaf"      # string
age = 21            # int
cgpa = 3.63         # float
is_student = True   # boolean

# %%
print(type(age))
# Out:
# <class 'int'>

# %%
city = "Sukkur"
year = 2025
print(city, age, name)
# Out:
# Sukkur 21 Sadaf

# %%
a = 10
b = 3
print(a + b)
print(a * b)
# Out:
# 13
# 30

# %%
print(a > b)
print(a == b)
# Out:
# True
# False

# %%
marks = 75
print(marks >= 50)
# Out:
# True

# %%
name = "Sadaf"
print(name.upper())
print(len(name))
# Out:
# SADAF
# 5

# %%
msg = "python internship"
print(msg.capitalize())
# Out:
# Python internship

# %%
marks = int(input("Enter marks: "))

if marks >= 85:
    print("A grade")
elif marks >= 70:
    print("B grade")
else:
    print("Need improvement")
# Out:
# Enter marks:  90
# A grade

# %%
skills = ["Python", "GitHub", "SQL"]
print(skills)
# Out:
# ['Python', 'GitHub', 'SQL']

# %%
print(skills[0])
# Out:
# Python

# %%
skills.append("Linux")

# %%
for skill in skills:
    print(skill)
# Out:
# Python
# GitHub
# SQL
# Linux
