# %%
skills = []
skill = input("Enter skills you are learning: ")
for i in range(3):
    skills.append(skill)

print("Your Skills:")
for s in skills:
    print("-", s)
# Out:
# Enter skills you are learning:  python
# Your Skills:
# - python
# - python
# - python
